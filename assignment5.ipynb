# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

# %%
pd.read_csv('005930 Historical Data.csv')
# Out:
#             Date   Price    Open    High     Low    Vol. Change %
# 0   May 06, 2021  82,300  81,800  82,300  81,700  16.85M   -0.36%
# 1   May 05, 2021  82,600  82,600  82,600  82,600       -    0.00%
# 2   May 04, 2021  82,600  81,900  82,600  81,800  12.29M    1.10%
# 3   May 03, 2021  81,700  81,000  82,400  81,000  15.58M    0.25%
# 4   May 02, 2021  81,500  81,500  81,500  81,500       -    0.00%
# 5   Apr 30, 2021  81,500  81,900  82,100  81,500  17.26M   -0.24%
# 6   Apr 29, 2021  81,700  82,400  82,400  81,500   2.84K   -0.49%
# 7   Apr 28, 2021  82,100  83,100  83,200  82,100   6.80K   -0.97%
# 8   Apr 27, 2021  82,900  83,300  83,300  82,500   3.86K   -0.72%
# 9   Apr 26, 2021  83,500  82,900  83,500  82,600   3.37K    0.85%
# 10  Apr 25, 2021  82,800  82,800  82,800  82,800       -    0.00%
# 11  Apr 23, 2021  82,800  81,900  82,900  81,600  17.74M    0.49%
# 12  Apr 22, 2021  82,400  82,800  83,000  82,400   8.15K   -0.24%
# ...

# %%
apple = pd.read_csv('005930 Historical Data.csv')
type(apple)
# Out:
# pandas.core.frame.DataFrame

# %%
plt.plot(apple.Date, apple.Price, '-')

plt.show()

# %%
from matplotlib import pyplot as plt
import numpy as np
# %matplotlib inline
import math
x=np.arange(0, math.pi*2, 0.05)
y=np.sin(x)
plt.plot(x,y,'k+')
plt.xlabel("angle")
plt.ylabel("sine")
plt.title('sine wave')

plt.show()

# %%
from matplotlib import pyplot as plt
import numpy as np
# %matplotlib inline
import math
x = np.arange(0, math.pi*2, 0.05)
y = np.tan(x)
plt.plot(x,y, 'c')
plt.xlabel("angle")
plt.ylabel("Tan value")
plt.title('Tan wave')
plt.show()

# %%
from matplotlib import pyplot as plt
import numpy as np
# %matplotlib inline
import math
x=np.arange(0, math.pi*2, 0.05)
y=np.cos(x)
plt.plot(x,y, 'yH')
plt.xlabel("angle")
plt.ylabel("cosine")
plt.title('cosine wave')

plt.show()

# %%
from numpy import *
from pylab import *
x = linspace(-3, 3, 30)
y = x**3
plot(x, y, 'b^--')
show()

# %%
from numpy import *
from pylab import *
x = linspace(-3, 3, 30)
y = x**5
plot(x, y, 'r.')
show()

# %%
from numpy import *
from pylab import *
x = linspace(-10, 8, 20)
y = x**2
plot(x, y, 'cx')
show()

# %%
from pylab import *
plot(x, sin(x), 'k--', label = 'sinx')
plot(x, cos(x), 'm-', label = 'cosx')
plot(x, -sin(x), 'y--', label = '-sinx') 

plt.title("WAVES", fontdict = {"fontname": "Algerian", "fontsize": 18 })
plt.savefig('waves.png', dpi = 1000 )

show()

# %%
from matplotlib import pyplot as plt
import numpy as np
import math
x=np.arange(0, math.pi*2, 0.05)
y=np.sin(x)
fig=plt.figure()
ax=fig.add_axes([0,0,1,1])
ax.plot(x,y, 'g--')

ax.set_title("sine wave")
ax.set_xlabel('angle')
ax.set_ylabel('sine')

plt.xticks([0,1,2,3,])
plt.yticks([0,1,2,3,])

plt.show()

# %%
import matplotlib.pyplot as plt 
x = []
for i in range(4):
    x.append(i)
y = []
for i in range(4):
    y.append(-i**3 + i**2 + i*5 - 1)
plt.plot(x,y, 'mD')
    
x = []
for i in range(4):
    x.append(i)

y = []
for i in range(4):
    y.append(i**3 + i**2 + i*5 - 1)
    
plt.plot(x,y, 'ko')

x = []
for i in range(4):
    x.append(i)

y = []
for i in range(4):
    y.append(4*i**2 + i*5 - 1)
    
plt.plot(x,y, 'rH')
plt.show()

# %%
import matplotlib.pyplot as plt
y = [1, 4, 9, 16, 25,36,49, 64]
x1 = [1, 16, 30, 42,55, 68, 77,88]
x2 = [1,6,12,18,28, 40, 52, 65]

fig=plt.figure()
ax=fig.add_axes([0,0,1,1])
l1=ax.plot(x1,y,'rs-') 
l2=ax.plot(x2,y,'mH--') 
ax.legend(labels=('tv', 'Smartphone'), loc='upper left') 

ax.spines['bottom'].set_color('blue')
ax.spines['left'].set_color('c')
ax.spines['left'].set_linewidth(2)
ax.spines['right'].set_color('yellow')
ax.spines['top'].set_color('green')

ax.set_title("Advertisement effect on sales")
ax.set_xlabel('medium')
ax.set_ylabel('sales')
plt.show()

# %%
import matplotlib.pyplot as plt
plt.plot([1,2,3])
plt.subplot(211, facecolor='c')
plt.plot(range(12),'k')
plt.subplot(212, facecolor='w')
plt.plot(range(12))

# %%
import matplotlib.pyplot as plt
fig=plt.figure()
ax1=fig.add_subplot(111)
ax1.plot([1,2,3,4,5,6],'kH')
ax2=fig.add_subplot(223, facecolor='c')
ax2.plot([1,2,3])

# %%
import matplotlib.pyplot as plt
import numpy as np
import math
x=np.arange(0, math.pi*2, 0.05)
fig=plt.figure()
axes1 = fig.add_axes([0.1, 0.1, 0.8, 0.8]) 
axes2 = fig.add_axes([0.55, 0.55, 0.3, 0.3])
y=np.tan(x)
axes1.plot(x, y, 'b')
axes2.plot(x,np.cos(x),'r')
axes1.set_title('tangent')
axes2.set_title("cosine")
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np
import math
x = np.arange(0, math.pi*2, 0.05)
fig=plt.figure()
axes1 = fig.add_axes([0.1, 0.1, 0.8, 0.8]) # main axes
axes2 = fig.add_axes([0.55, 0.55, 0.3, 0.3]) # inset axes
axes3 = fig.add_axes([0.2, 0.3, 0.2, 0.3]) # inset axes
axes1.plot(x, np.sin(x), 'b')
axes2.plot(x,np.cos(x),'r')
axes3.plot(x,np.tan(x),'g')
axes1.set_title('sine')
axes2.set_title("cosine")
axes3.set_title("tangent")
plt.show()

# %%
import matplotlib.pyplot as plt
a1 = plt.subplot2grid((3,3),(0,0),colspan = 2)
a2 = plt.subplot2grid((3,3),(0,2), rowspan = 3)
a3 = plt.subplot2grid((3,3),(1,0),rowspan = 2, colspan = 2)

import numpy as np
x = np.arange(1,10)
a2.plot(x, x*x,'r')
a2.set_title('square')
a1.plot(x, np.exp(x),'b')
a1.set_title('exp')
a3.plot(x, np.log(x),'g')
a3.set_title('log')
plt.tight_layout()
plt.show()

# %%
import matplotlib.pyplot as plt
fig,a= plt.subplots(2,2)
import numpy as np
x=np.arange(1,5)
a[0][0].plot(x,x*x)
a[0][0].set_title('square')
a[0][1].plot(x,np.sqrt(x))
a[0][1].set_title('square root')
a[1][0].plot(x,np.exp(x))
a[1][0].set_title('exp')
a[1][1].plot(x,np.log10(x))
a[1][1].set_title('log')
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt

xlist = np.linspace(-3.0, 3.0, 100)
ylist = np.linspace(-3.0, 3.0, 100)

X, Y = np.meshgrid(xlist, ylist)
Z = np.sqrt(X**2 + Y**2)

fig,ax=plt.subplots(1,1)
cp = ax.contourf(X, Y, Z)
fig.colorbar(cp) 
ax.set_title('Filled Contours Plot')

ax.set_xlabel('x (cm)')
ax.set_ylabel('y (cm)')
plt.show()

# %%
import matplotlib.pyplot as plt
import seaborn as sns
x=['Sunday', 'Monday', 'Tuesday', 'Wednesday', 'Thursday', 'Friday', 'Saturday'] 
y=[10, 12, 11, 11.2, 9, 14, 10.1] 
my_plot = sns.stripplot(x, y);

my_plot.set(xlabel ='Day Names', ylabel ='Turn Over (In Million Dollars)') 

plt.title('Scatter Plot')
plt.show()
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
import matplotlib.pyplot as plt
import numpy as np
fig, axes = plt.subplots(1,3, figsize=(12,4))
x=np.arange(1,11)
axes[0].plot(x, x**(1/2), 'm',lw=2)
axes[0].grid(True)
axes[0].set_title('default grid')
axes[1].plot(x, np.log(x), 'yo')
axes[1].grid(color='b', ls='-.', lw=0.25)
axes[1].set_title('custom grid')
axes[2].plot(x,x, 'k+')
axes[2].set_title('no grid')
fig.tight_layout()
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np
fig, axes = plt.subplots(1, 2, figsize=(10,4))
x=np.arange(1,5)
axes[0].plot( x, np.exp(x))
axes[0].plot(x,x**2)
axes[0].set_title("Normal scale")
axes[1].plot (x, np.exp(x))
axes[1].plot(x, x**2)
axes[1].set_yscale("log")
axes[1].set_title("Logarithmic scale (y)")
axes[0].set_xlabel("x axis")
axes[0].set_ylabel("y axis")
axes[0].xaxis.labelpad = 10
axes[1].set_xlabel("x axis")
axes[1].set_ylabel("y axis")

plt.show()

# %%
import matplotlib.pyplot as plt
fig=plt.figure()
a1=fig.add_axes([0,0,1,1])
import numpy as np
x=np.arange(1,10)
a1.plot(x, np.exp(x)**2)
a1.set_title('exp')

fig=plt.figure()
a1=fig.add_axes([0,0,1,1])
import numpy as np
x=np.arange(1,10)
a1.plot(x, np.exp(x)**2)
a1.set_title('exp')
a1.set_ylim(0,1000)
a1.set_xlim(0,10)

plt.show()
